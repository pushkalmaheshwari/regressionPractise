# %% [markdown]
# notebook to collate data from different sheet to one big sheet and sort it first by date and then by time.

# %%
outputfilename ='/Users/maheshwarip/Documents/dataScience/char_nifty_reg/combinedNifty.csv'

import os
import fileinput
with open(outputfilename, 'w') as outfile:
    for (dirname, dirs, files) in os.walk('/Users/maheshwarip/Documents/dataScience/char_nifty_reg/drive-download-20171231T112256Z-001'):
        for filename in files:
            if ( filename == 'NIFTY.txt' or filename == 'NIFTY.csv'  or filename == 'NIFTY.CSV'):
                print(filename)
                with open(dirname+ '/' +filename) as infile:
                    for line in infile:
                        outfile.write(line)
# Out:
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# BANKNIFTY.txt
# NIFTY.txt
# ...
